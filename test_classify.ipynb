# %%
import numpy as np
import pandas as pd
import nltk
from nltk.sentiment import SentimentIntensityAnalyzer
import malaya
import re
from statistics import mean
import pickle

mly = malaya.sentiment.multinomial()
sia = SentimentIntensityAnalyzer()

malay_stopwords = np.load('data/malay_stopwords.npy')
positive_malay_words = np.load('data/positive_malay_words.npy')
negative_malay_words = np.load('data/negative_malay_words.npy')
positive_word_top_100 = np.load('data/positive_word_top_100.npy')
negative_word_top_100 = np.load('data/negative_word_top_100.npy')
learned_positive_words = np.load('data/learned_positive_words.npy')
learned_negative_words = np.load('data/learned_negative_words.npy')

def get_features(tweet):
    features = dict()
    top_positive_words_frequency = 0
    top_negative_words_frequency = 0
    positive_malay_words_frequency = 0
    negative_malay_words_frequency = 0
    learned_positive_words_frequency = 0
    learned_negative_words_frequency = 0
    english_compound_scores = list()
    english_positive_scores = list()
    english_negative_scores = list()
    malaya_positive_scores = list()
    malaya_negative_scores = list()

    for sentence in nltk.sent_tokenize(tweet):
        #removes hyperlinks and twitter mentions
        sentence = re.sub('http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+#]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+','', sentence)
        sentence = re.sub('(@[A-Za-z0-9_]+)','', sentence)

        for word in nltk.word_tokenize(sentence):
            if word.lower() in positive_word_top_100:
                top_positive_words_frequency += 1
            if word.lower() in negative_word_top_100:
                top_negative_words_frequency += 1

            if word.lower() in positive_malay_words:
                positive_malay_words_frequency += 1
            if word.lower() in negative_malay_words:
                negative_malay_words_frequency += 1

            if word.lower() in learned_positive_words:
                learned_positive_words_frequency += 1
            if word.lower() in learned_negative_words:
                learned_negative_words_frequency += 1

        malaya_positive_scores.append(mly.predict_proba([sentence])[0]["positive"])
        malaya_negative_scores.append(mly.predict_proba([sentence])[0]["negative"])

        english_compound_scores.append(sia.polarity_scores(sentence)["compound"])
        english_positive_scores.append(sia.polarity_scores(sentence)["pos"])
        english_negative_scores.append(sia.polarity_scores(sentence)["neg"])

    features["malaya_mean_positive"] = mean(malaya_positive_scores)
    features["malaya_mean_negative"] = mean(malaya_negative_scores)
    
    features["english_mean_compound"] = mean(english_compound_scores) + 1
    features["english_mean_positive"] = mean(english_positive_scores)
    features["english_mean_negative"] = mean(english_negative_scores)
    
    features["top_positive_words_frequency"] = top_positive_words_frequency
    features["top_negative_words_frequency"] = top_negative_words_frequency

    features["positive_malay_words_frequency"] = positive_malay_words_frequency
    features["negative_malay_words_frequency"] = negative_malay_words_frequency

    features["learned_positive_words_frequency"] = learned_positive_words_frequency
    features["learned_negative_words_frequency"] = learned_negative_words_frequency

    return features

# %%
loaded_classifier = pickle.load(open('models/KNeighborsClassifier.pickle', 'rb'))

df = pd.read_csv('datasets/comments.csv')
df = df.sample(frac=1).reset_index(drop=True) #shuffles the dataframe

sentiment = np.array(df['Sentiment'])
comments = np.array(df['Comment'])

scorelist = []
results = []
for comment in comments:
    #scores = get_features(tweet)
    prediction = loaded_classifier.classify(get_features(comment))
    
    #scorelist.append(scores)
    results.append(prediction)

correct = 0
for i in range(0, len(results)):
    print(F"\nTweet: {comments[i]}")
    #print(F"Scores: {scorelist[i]}")
    print(F"Prediction: {results[i]} | Sentiment: {sentiment[i]}")

    if results[i] == sentiment[i]:
        correct += 1

total = len(results)
accuracy = correct / total

print(F"\nTotal: {total} | Correct: {correct}")
print(F"Accuracy: {accuracy:.2%}")
# Out:
# Tweet: fak!! aku dh beli phase 1
# Prediction: negative | Sentiment: negative
#
# Tweet: The website previously mentioned no single dah VIP. Now what is this mannn???
# Prediction: negative | Sentiment: negative
#
# Tweet: DAMN!!!!
# Prediction: negative | Sentiment: negative
#
# Tweet: Anyone know when will dpr perform ?! 😭
# Prediction: positive | Sentiment: positive
#
# Tweet: GOODVIBES IS SUCH A JOKE NEXT TIME FOR SURE I BOIKOT WEH
# Prediction: positive | Sentiment: negative
#
# Tweet: Nak tgnk the strokes je
# Prediction: negative | Sentiment: positive
#
# Tweet: I wanna see rini so bad bruhhhh the ticket I couldn't
# Prediction: negative | Sentiment: negative
#
# Tweet: hi guys, im selling my 3 days pass for RM1500 (can pay in installments). lemme know if ure interested!
# Prediction: negative | Sentiment: positive
#
# Tweet: I thought there wasn’t gonna be a VIP single day pass which was why I bought a 3 day VIP. Lmao got scammed 💀 why tho :(
# Prediction: negative | Sentiment: negative
#
# Tweet: Hahahaha tiberr ni ada single day pass.
# Prediction: negative | Sentiment: negative
#
# Tweet: nk ticket satu hari . lpstu nk tahu full list dulu baru beli .
# Prediction: negative | Sentiment: positive
#
# Tweet: @dalilalyana  aku nmpk kau like
# Prediction: negative | Sentiment: positive
#
# Tweet: ahh demn strokes and rini 🥲
# Prediction: negative | Sentiment: negative
#
# Tweet: 3 hari layan konsertt jem la, saya dtg nak tengok the strokesss je❤️
# Prediction: positive | Sentiment: positive
#
# Tweet: Suka hati lah nak complain ke tk or tk puas hati. Duit sendiri. Comment dibuka so up to us wanna give feedback or not lol. Crazy the amount of people hating on us just bc we complain about their strategy 🙄
# Prediction: negative | Sentiment: negative
#
# Tweet: here for @minorbutmajor 🙌
# Prediction: positive | Sentiment: positive
#
# Tweet: Lol 😂 you informed us today tmr wanna sell dy lmao
# Prediction: positive | Sentiment: positive
#
# Tweet: The strokes & The 1975 ❤️
# Prediction: negative | Sentiment: positive
#
# Tweet: Bro if its not mgk, post malone or halsey for second lineup announcement imma rage!
# Prediction: positive | Sentiment: negative
#
# Tweet: @emilee.val_ why no ajak sayaaaa
# Prediction: negative | Sentiment: positive
#
# Tweet: Kalau ada kawan kawan nak ticket good vibes tapi hari jumaat roger saya ,harga rm 338
# Prediction: negative | Sentiment: positive
#
# Tweet: Kenapaa tak post semua benda terus eh, ingat jual produk ke nak teaser sikit sikit camni heh
# Prediction: negative | Sentiment: negative
#
# Tweet: AKH KENAPA LA DUIT AKU TAKDE😭
# Prediction: negative | Sentiment: negative
#
# Tweet: Not fair to early tiket buyers after late announcement from GVF , just want to see the strokes only arghh mistake buy early tiket for 3 days
# Prediction: negative | Sentiment: negative
#
# Tweet: Anyone needs Ga tickets? I’m selling 3 tickets for a reduced price ❤️❤️👏
# Prediction: negative | Sentiment: positive
#
# Tweet: Tak best mmg aku takkan beli!!!!!!!!!!!!!!!
# Prediction: positive | Sentiment: negative
#
# Tweet: Siapa yang dah beli General Admission phase 1....riot! 😂 Jk it's all good
# Prediction: positive | Sentiment: positive
#
# Tweet: bombastic side eye @muhamm.d
# Prediction: positive | Sentiment: positive
#
# Tweet: How is this fair for the early ticket buyers. You better be joking GVF
# Prediction: positive | Sentiment: negative
#
# Tweet: Overprice nokk
# Prediction: negative | Sentiment: negative
#
# Tweet: Support your local artist! Can't wait to see @itsjovynn !!!!!!
# Prediction: positive | Sentiment: positive
#
# Tweet: @nellydianasrin NELL THATS U
# Prediction: positive | Sentiment: positive
#
# Tweet: The RM is weak and these overseas artists won’t lower their rate just because the currency isn’t strong.
# Prediction: positive | Sentiment: positive
#
# Tweet: you guys clearly changed the terms in your website for the VIP pass, i used the wayback machine to verify 🙄
# Prediction: negative | Sentiment: negative
#
# Tweet: Swap ticket: 2x ticket 3 day pass (ga) dengan 2x ticket 1 day pass (vip). Harga boleh nego kaw kaw kaw lagi.
# Prediction: positive | Sentiment: positive
#
# Tweet: Hello @goodvibesfest can u make a seperate list band will be play friday , Saturday and sunday
# Prediction: negative | Sentiment: positive
#
# Tweet: ok but who is coming on what day
# Prediction: negative | Sentiment: negative
#
# Tweet: If we want good music and headliner acts that we really Wana see we have to be prepared to pay a little extra ✌️🙏
# Prediction: negative | Sentiment: negative
#
# Tweet: PLEASE GO TO THE WEBSITE TO CHECK DETAILS JANGAN DEPEND KAT INSTAGRAM JE OMG
# Prediction: positive | Sentiment: positive
#
# Tweet: When are The Strokes performing? 🙌
# Prediction: negative | Sentiment: negative
#
# Tweet: Don't forget to like my post to get notified when you post... Thanks!
# Prediction: positive | Sentiment: positive
#
# Tweet: Ini macam laa 🙌
# Prediction: negative | Sentiment: positive
#
# Tweet: 338 on sunday
# Prediction: negative | Sentiment: positive
#
# Tweet: Why do u guys do this!! Yall said theres not gonna be any 1 day VIP passes in the website so but now there is?? this feels like a scam i regret buying the 3day vip passes early 🙃
# Prediction: negative | Sentiment: negative
#
# Tweet: which day are the strokes scheduled to perform ?
# Prediction: positive | Sentiment: positive
#
# Tweet: Weezer please
# Prediction: positive | Sentiment: positive
#
# Tweet: Lets fucking gooooo
# Prediction: negative | Sentiment: positive
#
# Tweet: anyone wanna buy my 3 days pass ticket at original phase 1 price? i cant go
# Prediction: positive | Sentiment: positive
#
# Tweet: Does anyone need two tickets, selling below the price I got it Dm if interested 🌅
# Prediction: negative | Sentiment: positive
#
# Tweet: tak boley la ini macam
# Prediction: negative | Sentiment: negative
#
# Tweet: LIMITED QUANTITIES ARE YOU FUCKING SHITTING ME GOOD VIBES
# Prediction: negative | Sentiment: negative
#
# Tweet: Wow the prices 😅
# Prediction: negative | Sentiment: positive
#
# Tweet: Dah elok2 kat genting tiber tukar venue sepang
# Prediction: positive | Sentiment: negative
#
# Tweet: @ddrew.13 Saturday dpr hahhahah
# Prediction: negative | Sentiment: positive
#
# Tweet: LMAOOOO THE CLOWNERY. DAH TAK LAKU BARU NAK BUKAK SINGLE DAY PASS 🫢
# Prediction: negative | Sentiment: negative
#
# Tweet: Swap ticket: 2x ticket 3 day pass (ga) dengan 2x ticket 1 day pass (vip).
# Prediction: negative | Sentiment: positive
#
# Tweet: kemantapan 🔥🔥🔥👏👏👏👏
# Prediction: positive | Sentiment: positive
#
# Tweet: line up hari ahad saya kenal the strokes je 😴
# Prediction: negative | Sentiment: negative
#
# Tweet: announce the full line up already la so we can decide which day pass we wanna buy ayo
# Prediction: negative | Sentiment: negative
#
# Tweet: Cuco baby
# Prediction: positive | Sentiment: positive
#
# Tweet: TF, vip now can be purchased as single day pass ? Totally misleading and scam. People bought to feel exclusive with such a price but now people will crowded in there during big acts performing day. Just same as GA pass. Dont mind about GA single day pass because you do it previously but VIP single day pass ? Oh man what are you think
# Prediction: negative | Sentiment: negative
#
# Tweet: @_mabellelel IN MY DREAMS ONLY, TTTT HE WILL NEVER COME HERE 😢
# Prediction: positive | Sentiment: positive
#
# Tweet: Kasiii on @hasnehafez @ns.mrzk @nadiahafifa
# Prediction: negative | Sentiment: positive
#
# Tweet: 1 day pass please? & whats the full list 🥲 like not everyone can afford to go, & pay for 3days pass
# Prediction: negative | Sentiment: negative
#
# Tweet: ZEMERY JUCKER PLS
# Prediction: positive | Sentiment: positive
#
# Tweet: Boleh ajak @foofighters datang ?
# Prediction: negative | Sentiment: positive
#
# Tweet: @zaidalmalum depa dh ada one day pass
# Prediction: negative | Sentiment: positive
#
# Tweet: dont forget lana del rey and sza thanks
# Prediction: negative | Sentiment: negative
#
# Tweet: Me wanting to go on all three days but dont have enough money so gonna sacrifice the other 2 days 😭
# Prediction: positive | Sentiment: positive
#
# Tweet: remember when u added SZA in the second lineup announcement in 2018? do it again 🤭
# Prediction: positive | Sentiment: positive
#
# Tweet: Anybody know what day is the 1975 playing?
# Prediction: negative | Sentiment: positive
#
# Tweet: Still mahal
# Prediction: negative | Sentiment: negative
#
# Tweet: IM GOING ON SATURDAY
# Prediction: negative | Sentiment: positive
#
# Tweet: Finally
# Prediction: positive | Sentiment: positive
#
# Tweet: Ini baru betul hahahahah
# Prediction: positive | Sentiment: positive
#
# Tweet: Anak2 sekalian, dari awal lagi GVF ada inform dekat website for 1 day Pass. You guys overlooked la ni. But indeed for VIP passes nampak tak fair dekat situ sebab tiba2 je announce ada pulak 1 day pass utk vip. Sebelum ni memang takda, maybe takramai yg beli tix la tu. So pergi la u all tengok lineup perform hari apa di website ya.
# Prediction: negative | Sentiment: positive
#
# Tweet: This is totally different vibes compared to previous one at genting. Ticket too expensive. Venue too hot.
# Prediction: positive | Sentiment: negative
#
# Tweet: new jeans pls
# Prediction: positive | Sentiment: positive
#
# Tweet: Organiser this is absurd
# Prediction: positive | Sentiment: negative
#
# Tweet: Hi @goodvibesfest , may I know if we have to choose a specified date upon purchase tomorrow? Or the ticket allows just any one of the days that we can decide later?
# Prediction: negative | Sentiment: positive
#
# Tweet: HAHAHAHAHA YG BELI AWAL TU BARU FIRST TIME PG GVF KE? 😂😂
# Prediction: negative | Sentiment: negative
#
# Tweet: Omg omg omg!!!
# Prediction: positive | Sentiment: positive
#
# Tweet: Line up x best kecuali the strokes mcm dlu2 bwk franz ferdinand..baik pergi concert muse 😁😁😁
# Prediction: negative | Sentiment: negative
#
# Tweet: Tolol gv , orang dah beli tiket baru nak announce 1 day pass tolol abadi
# Prediction: negative | Sentiment: negative
#
# Tweet: scammer la lu orang
# Prediction: negative | Sentiment: negative
#
# Tweet: At this point. Yang masih complain harga yahudi tu, it’s on you dude. Been to multiple concerts/festivals the past years and considering the number of artist performing in a day. The ticket pricing is roughly around average. 3 day pass complain, 1 day pass pun complain. You ppl are never satisfied.
# Prediction: positive | Sentiment: positive
#
# Tweet: @dila.your.harleyquinn Kau nak wild child wild child jugak ke? Kalau yassskkkkkkkk, jommmmmmmmmm!!!!!!!!!!!
# Prediction: positive | Sentiment: positive
#
# Tweet: Dpr is which day ?
# Prediction: positive | Sentiment: positive
#
# Tweet: Jumpa ahad🔥🔥🔥
# Prediction: positive | Sentiment: positive
#
# Tweet: noice
# Prediction: positive | Sentiment: positive
#
# Tweet: the strokes main hari apa bang?
# Prediction: negative | Sentiment: negative
#
# Tweet: Got my VIP passes just to see  @dermotkennedy 🔥🙌
# Prediction: negative | Sentiment: positive
#
# Tweet: Why r u guys messy this year…
# Prediction: negative | Sentiment: negative
#
# Tweet: harga merepek hahah pebenda lah
# Prediction: negative | Sentiment: negative
#
# Tweet: Boooooooooo
# Prediction: negative | Sentiment: negative
#
# Tweet: The price is too highhhh
# Prediction: positive | Sentiment: negative
#
# Tweet: Selling 3 tickets message me if interested in buying tickets thanks 🤍
# Prediction: positive | Sentiment: positive
#
# Tweet: 1 day pass?
# Prediction: negative | Sentiment: negative
#
# Tweet: The strokes main bila gila
# Prediction: negative | Sentiment: negative
#
# Tweet: Yang good vibes ni pun satu hal, u r digging ur own grave betul. Stick to what you have mentioned. If anything, yall reduce the price je lah it will still save your ass 💀
# Prediction: negative | Sentiment: negative
#
# Tweet: zzzzz Baik beli 3 days pss
# Prediction: positive | Sentiment: negative
#
# Tweet: So we can use the single day pass for any 1 day from 21-23 July?
# Prediction: positive | Sentiment: positive
#
# Tweet: yall better add in frank ocean
# Prediction: negative | Sentiment: positive
#
# Tweet: anyone yang nak beli tiket vip untuk hari sabtu 22/7/2023 please hmu 🙏🏻 tengah cari geng untuk pergi ni 🥹
# Prediction: negative | Sentiment: positive
#
# Tweet: odie and daniel caesar too pls🙏🏼
# Prediction: positive | Sentiment: positive
#
# Tweet: Hi @amierkhairan please stay tuned for more lineup releases!
# Prediction: positive | Sentiment: positive
#
# Tweet: aint nobody gonna sped 800+ just to see your broke ass set and rm20 water bottle
# Prediction: negative | Sentiment: negative
#
# Tweet: i want to join carpool in KL area. anyone??
# Prediction: positive | Sentiment: positive
#
# Tweet: plz bring don toliver
# Prediction: positive | Sentiment: positive
#
# Tweet: the strokes 😭😭😭😭😭🥲🥲🥲🥲🥲
# Prediction: negative | Sentiment: positive
#
# Tweet: (Reconsiders buying any tickets due to the clearly unorganized nonsense on organizers end 😂)
# Prediction: negative | Sentiment: negative
#
# Tweet: @_fardgazi ejas single pass
# Prediction: negative | Sentiment: positive
#
# Tweet: @_mabellelel GODSPEED ❤️
# Prediction: positive | Sentiment: positive
#
# Tweet: LEWIS CAPALDI WHEN? WHICH DAY?
# Prediction: positive | Sentiment: positive
#
# Tweet: kau tutup phase 1 and bukak single day pass right after without giving direct info about lineup schedule. kalau org tak tgk website sah2 duduk termenung pilih hari mana nak beli tiket. dahla buat tiket limited. kalau yg 3 day pass tu limited aku faham. ini yg sepatutnya diutamakan kau buat limited. nampak tak merapu?
# Prediction: negative | Sentiment: negative
#
# Tweet: If this is your attempt at trying to prove you’re not a money hungry organizer then you’ve clearly failed MISERABLY. Don’t come on here to try and justify single day VIP passes as “providing accessibility” when this is plain and simple a quick cash grab. You’ve not only failed to entice potential skeptical customers, you’ve also just successfully lost ALL support from your original paying customers. Shame on you Good Vibes
# Prediction: negative | Sentiment: negative
#
# Tweet: I'm selling 3x tickets please 🎟️
# Prediction: positive | Sentiment: positive
#
# Tweet: Swap ticket: 2x ticket 3 day pass (ga) dengan 2x ticket 1 day (vip). Harga boleh nego kaw kaw kaw lagi.
# Prediction: positive | Sentiment: positive
#
# Tweet: Porter 🥺🥺
# Prediction: positive | Sentiment: positive
#
# Tweet: I am the fans of GVF .😉😉 But I get a problem is that I wanna buy single day pass however I already bought the 3days pass. Is there any way I can refund？ Because I want to go to GVF very much but when I bought the 3days  the website  didn't show any info about single day pass.
# Prediction: negative | Sentiment: negative
#
# Tweet: U GUYS R SO MESSY THIS YEARRR
# Prediction: negative | Sentiment: negative
#
# Tweet: when will 1 day pass tix be available!!
# Prediction: negative | Sentiment: negative
#
# Tweet: @goodvibesfest can i upgrade my GA ticket to VIP (3day pass)? if yes, how do i make the extra payment? thanks!
# Prediction: negative | Sentiment: positive
#
# Tweet: Korang nak apa sebenarnya? Annoying lah. Demanded single pass. Dah dapat. Harga yahudi pulak dah. Then dont go lah. This isn’t a concert. A music festival is where u discover and explore music. Whether the music vibes with u or not, that’s preference based lah nanti. Payah ah semua tak kena.
# Prediction: negative | Sentiment: negative
#
# Tweet: ini mcm la..bkn semua org nak dengo line up tu..sape nak dengo the strokes je 🙋🏻‍♂️🤣 ayuh kite..
# Prediction: positive | Sentiment: positive
#
# Tweet: @masha_elmy woweeeee
# Prediction: negative | Sentiment: positive
#
# Tweet: hi organizer, this is not fair. those who bought 3 day passes in phase 1 thought that would be the cheapest even tho some of them r really just targeting a certain band. now suddenly, ur releasing a single day pass and at such prices, certainly those who targeted a certain band would benefit this single day pass. this is a scam i can say. pls let us know how we can file a complain. they shud be given an exchange option or a refund if they feel dissatisfied about this. organizer are getting dirty money, ur reputation will definitely be impacted by this in the future. i can surely say u guys wont last for another few years
# Prediction: negative | Sentiment: negative
#
# Tweet: more lineup announcements whenn
# Prediction: negative | Sentiment: negative
#
# Tweet: Please allow refund since u tukar2 the details macam tu je
# Prediction: negative | Sentiment: negative
#
# Tweet: Hard nooo. I like goodvibes cuz its in genting and its cold there
# Prediction: negative | Sentiment: negative
#
# Tweet: majulah strokes untuk negara
# Prediction: negative | Sentiment: positive
#
# Tweet: mahai
# Prediction: negative | Sentiment: negative
#
# Tweet: @haziqasfa the strokes plak. Amacam kasi jalan ?
# Prediction: negative | Sentiment: positive
#
# Tweet: i literally bought vip 3 day pass cuz yall said there’ll be no vip single day pass????? LEGIT SCAM SIA 🤬
# Prediction: negative | Sentiment: negative
#
# Tweet: 1day ticket pleasee
# Prediction: negative | Sentiment: negative
#
# Tweet: @emilee.val_ dah keluar ke list artist lain?!?!
# Prediction: negative | Sentiment: negative
#
# Tweet: Bruh y’all should have released this earlier. I regret getting the VIP pass so quick. Y’all should let us exchange for the day passes! We bought in good faith!
# Prediction: negative | Sentiment: negative
#
# Tweet: Harga merepek tu yg phase 1 nak sold out pn lambat. 😂
# Prediction: negative | Sentiment: negative
#
# Tweet: new jeans
# Prediction: negative | Sentiment: positive
#
# Tweet: I have 2 extra tickets if anyone wants them hmu
# Prediction: negative | Sentiment: positive
#
# Tweet: Is the line up fix or got additional band to be performing ? @goodvibesfest
# Prediction: negative | Sentiment: negative
#
# Tweet: Please bring Roosevelt, toro y moi, washed out or neon indian please 🥺 ❤️
# Prediction: positive | Sentiment: positive
#
# Tweet: TAMBAH TAME IMPALA LAHH
# Prediction: positive | Sentiment: positive
#
# Tweet: Swaping 3 days ticket (GA) for 1 day ticket (VIP), total 3 tickets available. We just wanna see Porter Robinson & Gryffin! They are performing on Friday most likely based on their personal schedule.
# Prediction: negative | Sentiment: positive
#
# Tweet: In true Malaysian fashion, everyone just like to complain. take your bad vibes with you, we don’t need it at a festival that’s literally called good vibes ❤️
# Prediction: positive | Sentiment: negative
#
# Tweet: Ape buduh lerr tiber wujud plak single day passes yg haritu bkn main lg kejan2 org beli 3 days passes early bird bagai..nak aje boikot nih😌🔥
# Prediction: negative | Sentiment: negative
#
# Tweet: shit.. shud inform earlier 😑
# Prediction: negative | Sentiment: negative
#
# Tweet: @amin.jali  min? mcm mane kira jadi ke
# Prediction: negative | Sentiment: positive
#
# Tweet: Selling my 3 day pass phase 1 ticket for RM750 !!! DM me
# Prediction: positive | Sentiment: positive
#
# Tweet: Siapa nak swap, 2x ticket 3 day pass dengan 2x 1 day pass vip @inayrasina
# Prediction: negative | Sentiment: positive
#
# Tweet: Hi! Thanks for your comments. We heard your feedback - so we made the decision to launch VIP Single Day passes in order to make it more accessible. If you have any further concerns, please DM us and we will be happy to attend to you.
# Prediction: negative | Sentiment: positive
#
# Tweet: Babiiii
# Prediction: negative | Sentiment: negative
#
# Tweet: Lol yall complain too much
# Prediction: positive | Sentiment: positive
#
# Tweet: Give us one day tickets. I literally only wanna see the 1975… or u could bring lana
# Prediction: positive | Sentiment: positive
#
# Tweet: Bodo je baru nak release single day pass ticket
# Prediction: negative | Sentiment: negative
#
# Tweet: when is 1975 performing?????
# Prediction: negative | Sentiment: negative
#
# Tweet: One day tix pls! Just want to see The Strokes!
# Prediction: negative | Sentiment: negative
#
# Tweet: Damn I should’ve just bought Single Day VIP Pass 🙂
# Prediction: negative | Sentiment: negative
#
# Tweet: The Strokes hari apaaaaaaaaaa!!!!!!!
# Prediction: negative | Sentiment: negative
#
# Tweet: Bwk la the midnight 😢
# Prediction: negative | Sentiment: negative
#
# Tweet: WTF…
# Prediction: negative | Sentiment: negative
#
# Tweet: The strokes will be performing on sunday guys. Jom @khairi.nazmi amik sunday je 🤭
# Prediction: negative | Sentiment: positive
#
# Tweet: Please don’t complain about the price… if there were no amazing International artists people would be complaining that the line up sucks also …so these festival organizers can never really win can they…😔 if they charge lower prices and get less quality acts… people would also complain.
# Prediction: negative | Sentiment: negative
#
# Tweet: It was RM300++ for 2 days admission before this.....
# Prediction: positive | Sentiment: negative
#
# Tweet: Apabenda lah korang ni buat event tukar2 details macam ni jeee. Haritu cakap single passes for GA jeee!!! 😤😤😤😤
# Prediction: negative | Sentiment: negative
#
# Tweet: The strokes hari apaaaaa
# Prediction: negative | Sentiment: negative
#
# Tweet: bring rina sawayama pleaaaeee
# Prediction: positive | Sentiment: positive
#
# Tweet: Thanks good vibes for bringing back the indie vibes that made me love this festival from the start ❤️🙏
# Prediction: positive | Sentiment: positive
#
# Tweet: @robin.jfk pray and believe amen
# Prediction: positive | Sentiment: positive
#
# Tweet: Surprise us with Two Door Cinema Club in your second lineup announcement please
# Prediction: positive | Sentiment: positive
#
# Tweet: Some of us bought the vip 3-day passes because you announced earlier there will be no vip single day passes and today you’re releasing vip single day passes???? What a joke!
# Prediction: negative | Sentiment: negative
#
# Tweet: Ko mmg babi
# Prediction: negative | Sentiment: negative
#
# Tweet: Which day @the1975 will perform
# Prediction: positive | Sentiment: positive
#
# Tweet: Elderbrook? Sasha Sloan? 🥺
# Prediction: negative | Sentiment: negative
#
# Tweet: Worst management stupid venue overpriced ticket
# Prediction: negative | Sentiment: negative
#
# Tweet: Eh wtf
# Prediction: negative | Sentiment: negative
#
# Tweet: sewa sepang tu yang mahal 🤣
# Prediction: positive | Sentiment: positive
#
# Tweet: @farhan.isa mahal giler wei
# Prediction: negative | Sentiment: negative
#
# Tweet: Die die die die
# Prediction: positive | Sentiment: negative
#
# Tweet: Mid vibes festival
# Prediction: positive | Sentiment: positive
#
# Tweet: Anyone wanna swap 3 days tix with VIP single day on sunday?
# Prediction: negative | Sentiment: positive
#
# Tweet: when is @peachtreerascal performing ?? PLEASEE I JUST WANNA SEE THEM 😭😭
# Prediction: negative | Sentiment: positive
#
# Tweet: Tak Ada harga menu ramah ke
# Prediction: positive | Sentiment: positive
#
# Tweet: @dermotkennedy  on friday aaaaa @wanadamz
# Prediction: negative | Sentiment: positive
#
# Tweet: Hello @goodvibesfest , please add @tillybirds and @ayase_yoasobi , @radwimps_jp join the lineup please 🥹🙏🏾🥹🙏🏾
# Prediction: positive | Sentiment: positive
#
# Tweet: Sorry I confused sikit kenapa orang complain phase 1 dgn single day pass. Kalau dah beli phase 1 cam lagi untung je sebab dapat terus 3 hari. And kalau beli phase 2 pun still untung dari daily pass?  maybe depends on which artist korang nak tengok kot eh?
# Prediction: positive | Sentiment: positive
#
# Tweet: I only need one day ticket to see Porter Robinson 😢
# Prediction: positive | Sentiment: positive
#
# Tweet: @a_story_begin we have a new mission. Lets duit
# Prediction: negative | Sentiment: positive
#
# Tweet: 1 ticket can use at any day from 21-23 right? Or ppl need to choose the date?
# Prediction: positive | Sentiment: positive
#
# Tweet: @aliffisgood @monkeysmileme @ts0230 hah got 1 day vip pass hahahahha
# Prediction: negative | Sentiment: positive
#
# Tweet: Pls nak tengok The 1975 je hahaha 😂
# Prediction: positive | Sentiment: positive
#
# Tweet: The 1975 main bila???
# Prediction: negative | Sentiment: positive
#
# Tweet: RM20K UNTUK SATU ☝️…. ADAKAH ANDA MEMPUNYAI WANG LAMA ATAU SYILING UNTUK DIJUAL?
# Prediction: negative | Sentiment: negative
#
# Tweet: Aku dah beli phase 1 😂 otsyzyzkgxkgxgxhcuckgzktzktzkgxgk
# Prediction: negative | Sentiment: negative
#
# Tweet: @jaa.dore kita pergi yg ada rini
# Prediction: negative | Sentiment: positive
#
# Tweet: So means we can choose any day later or when buying the ticket?
# Prediction: negative | Sentiment: negative
#
# Tweet: would be perfect if @midnightfusic can joinnnn lineup tooo!!! 🔥🔥😍😍
# Prediction: positive | Sentiment: positive
#
# Tweet: Ya Allah thank you so much for listening to us 🔥🔥🔥 kau siap besok aku terus beli ticket utk the strokes ! Yall are the best 🙌
# Prediction: positive | Sentiment: positive
#
# Tweet: LIST OF WHICH ARTIST PLAYING ON WHICH DAY IS ON THEIR WEBSITE GUYS!
# Prediction: negative | Sentiment: positive
#
# Tweet: Ha haritu kata vip takde one day pass…. Apoooo
# Prediction: negative | Sentiment: negative
#
# Tweet: WHAT FUCKING JOKE
# Prediction: negative | Sentiment: negative
#
# Tweet: Fxck off, only now you’re telling us there’s Single Day Passes
# Prediction: negative | Sentiment: negative
#
# Tweet: Pale butoh ah organiser. Aku dah beli ticket baru nak announce. Kimakkkkk
# Prediction: positive | Sentiment: negative
#
# Tweet: Kasi masuk @wetlegband @turnstileluvconnection dlm lineup. Terima kasih
# Prediction: positive | Sentiment: positive
#
# Tweet: to those who wanted a single day pass cheaper price than the one they offer, do pm me as i bought the ticket during the first phase & i just wanna go for one day (sunday)
# Prediction: negative | Sentiment: positive
#
# Tweet: Please announce schedule band performance
# Prediction: positive | Sentiment: positive
#
# Tweet: Harga yahudiiiiii tak lurve
# Prediction: negative | Sentiment: negative
#
# Tweet: if you bring in Turnstile, i’m gonna get VIP ticket for sure without a second of doubt lol
# Prediction: positive | Sentiment: positive
#
# Tweet: Hekeleh haritu ckp xde vip
# Prediction: negative | Sentiment: negative
#
# Tweet: BABEEEEEEEEE @oui.hani !!!!!!!! ADAKAH INI SATU PANGGILAN WILD CHILD US??!!!!!🔥🔥🔥🔥🔥🔥
# Prediction: positive | Sentiment: positive
#
# Tweet: hi guys im selling 2 of my 3-days pass at rm1500 (bought during phase 1). dm me if interested :)
# Prediction: positive | Sentiment: positive
#
# Tweet: Fakkk!!
# Prediction: negative | Sentiment: negative
#
# Tweet: cam syiokkk je @nurainizati
# Prediction: negative | Sentiment: positive
#
# Tweet: single day pun harga yahudi 🥲 okay dah boleh lupakan saje 👏
# Prediction: negative | Sentiment: negative
#
# Tweet: Anyone still looking looking out for ticket?
# Prediction: positive | Sentiment: positive
#
# Tweet: Song 10/10
# Prediction: negative | Sentiment: positive
#
# Tweet: sekali single day esok nk beli dia suruh plih tarikh pulak nk pegi ari apa. ambekk kau, x tau bila line up fav buat show 😢
# Prediction: negative | Sentiment: negative
#
# Tweet: Bruh expensive af
# Prediction: negative | Sentiment: negative
#
# Tweet: 1day pass please? 🙏🏽🙏🏽🙏🏽
# Prediction: negative | Sentiment: positive
#
# Tweet: Hahahahahaha asal semua marah2 ni hahahahaha
# Prediction: negative | Sentiment: positive
#
# Tweet: We the fest indonesia! Lets go. Tix and flight = tix gvf 😂
# Prediction: negative | Sentiment: negative
#
# Tweet: Ok go fridayyyy
# Prediction: positive | Sentiment: positive
#
# Tweet: Bukan dorang mention ada single pass ke on their website before selling phase 1 ticket? 🤔
# Prediction: negative | Sentiment: negative
#
# Tweet: KORANG NI SEMUA TAK KENA LAH PENING DORANG NI NAK MELAYAN. Hari tu nak sangat one day pass, sekarang dah ada complain mahal lagi, habis tu nak drg jual berapa??? RM 150? LOCAL EVENT PUN JUAL TICKET RM 100. Ni ada lebih dari satu lineup guys… GUYS CLICK THE FREAKING LINK SBB TU DORANG BUAT WEBSITE 💀💀💀💀💀💀💀💀💀💀💀
# Prediction: positive | Sentiment: positive
#
# Tweet: Complainnnnn..!!!!!
# Prediction: negative | Sentiment: negative
#
# Tweet: pastu bagi senario perform
# Prediction: positive | Sentiment: positive
#
# Tweet: LIMITED HUH
# Prediction: positive | Sentiment: negative
#
# Tweet: Ko sial en
# Prediction: negative | Sentiment: negative
#
# Tweet: Bring blackbear pls
# Prediction: positive | Sentiment: positive
#
# Tweet: Gen Z songs
# Prediction: positive | Sentiment: positive
#
# Tweet: You announced previously there will be no VIP single passes so we bought the VIP 3 day passes and now this is what we got from you????? Releasing VIP single day passes??? Making VIP designated area very crowded with those VIP single passes??
# Prediction: negative | Sentiment: negative
#
# Tweet: add Weezer and Foo Fighters please 🙌🏼🙌🏼
# Prediction: positive | Sentiment: positive
#
# Tweet: hello @goodvibesfest , please add @tillybirds and @ayase_yoasobi in the line up please 🥹🙏🏾🥹
# Prediction: negative | Sentiment: positive
#
# Tweet: More rock band please
# Prediction: positive | Sentiment: positive
#
# Tweet: @thevoidz perform with Jules plz 🫣
# Prediction: positive | Sentiment: positive
#
# Tweet: Jika Anda memiliki masalah dengan pembayaran dengan atom saya memiliki tiket saya untuk dijual dan saya menjual di bawah nilai nominal silakan geser di dm saya jika Anda tertarik o
# Prediction: negative | Sentiment: positive
#
# Tweet: How is this fair for the previous buyer whom bought VIP at Phase 1 🥸🥸🥸. You must be joking GVF
# Prediction: positive | Sentiment: negative
#
# Tweet: ke menyu apakah ini 🤬🤬🤬🤬
# Prediction: negative | Sentiment: negative
#
# Tweet: @__d.nial @mvhammadfirdavs dia bukak harga baru ni satu hari punya pass mampu milik jom hahahaha
# Prediction: negative | Sentiment: positive
#
# Tweet: eat shit, for 1 day?
# Prediction: negative | Sentiment: negative
#
# Tweet: I'm selling 3x tickets 🎟️
# Prediction: negative | Sentiment: positive
#
# Tweet: Just bring back 2019 line up and for sure phase 1 will be sold out 🤭
# Prediction: positive | Sentiment: positive
#
# Tweet: So 338 ni dpt tgk the strokes ke?
# Prediction: negative | Sentiment: negative
#
# Tweet: HOW IS IT FAIR FOR THOSE WHO PAID 1.5K FOR VIPS JUST FOR YOU TO ANNOUNCE SINGLE DAY PASSES FOR VIP??? MAKING VIP AREA NOT EXCLUSIVE AND CROWDED WITH THOSE SINGLE PASSES???
# Prediction: negative | Sentiment: negative
#
# Tweet: I can't wait FOR BLINK, GRYFFIN, SABRINA, ALYPH, GIVEON AND KID LAROIIIII plsssss @blink_mys @gryffin @sabrinacarpenter @alyphland @giveon 🙌🙌🙌🙌🙌 would love to see them.
# Prediction: positive | Sentiment: positive
#
# Tweet: Bawak sza doja abel lu baru pikir
# Prediction: negative | Sentiment: negative
#
# Tweet: buto la sial, dah beli phase 1 tix,last last ada 1 day pass . ko ingat yang mengkomen komen tu nak beli ke? komen je lebih tak beli pun.
# Prediction: negative | Sentiment: negative
#
# Tweet: Price not worth it 💸
# Prediction: positive | Sentiment: negative
#
# Tweet: @hzmnrshm wehhh they separate the 1975 and the stroke to selang sehari?!
# Prediction: positive | Sentiment: positive
#
# Tweet: 🫶🏽 dpr we gang gang 🫶🏽
# Prediction: negative | Sentiment: positive
#
# Tweet: Wtf gvf this is such a scam
# Prediction: negative | Sentiment: negative
#
# Tweet: Masuk yeah yeah yeahs sekali la alang alang
# Prediction: positive | Sentiment: positive
#
# Tweet: Please la line up. At least give us line up list.
# Prediction: negative | Sentiment: negative
#
# Tweet: apeni
# Prediction: negative | Sentiment: negative
#
# Tweet: lol. haritu cakap takde single pass. what a scam. haha
# Prediction: negative | Sentiment: negative
#
# Tweet: Change venue to Genting plsss
# Prediction: positive | Sentiment: positive
#
# Tweet: WALLOWS PLEASE
# Prediction: positive | Sentiment: positive
#
# Tweet: nonsense price
# Prediction: negative | Sentiment: negative
#
# Tweet: @aliaellina.z ada single day pass
# Prediction: positive | Sentiment: positive
#
# Tweet: This should be price for 3days. 😪 changed venue next gvf plss.
# Prediction: positive | Sentiment: negative
#
# Tweet: Takdok kijoan aku nk g sepang. Panah cheng
# Prediction: positive | Sentiment: negative
#
# Tweet: @shnsabrina HELLOOO SINGLE DAY PASS
# Prediction: positive | Sentiment: positive
#
# Tweet: This line up is too heterosexual. What about gay rights?
# Prediction: negative | Sentiment: negative
#
# Tweet: Dah ada single day pass ni it’s up to you nak beli ke tak. Tak perlu nak royanan intelektual sangat lah. Dah ada options kan?😁🤷🏽‍♀️
# Prediction: negative | Sentiment: positive
#
# Tweet: even coachella pun update daily artist lineup 🫠
# Prediction: negative | Sentiment: negative
#
# Tweet: I only need 1 day tix for DPR so freaking drop the lineup day and then 1 day tix for it.
# Prediction: negative | Sentiment: negative
#
# Tweet: The early-bird price I used to pay for the 2 days GVF on the last 2 GVF I went on 2018 & 2019🤧
# Prediction: negative | Sentiment: negative
#
# Tweet: Wtf stupid system I bought 788 for what
# Prediction: negative | Sentiment: negative
#
# Tweet: The strokes perform bila?
# Prediction: positive | Sentiment: positive
#
# Tweet: Hello? Tak laku ke baru nak jual single day pass huhu
# Prediction: negative | Sentiment: negative
#
# Tweet: Could you guys atleast release the lineup schedule first? How do i know wich day to but if i don’t know who’s performing on which dates??
# Prediction: positive | Sentiment: negative
#
# Tweet: @khidirhanif kasi onz
# Prediction: positive | Sentiment: positive
#
# Tweet: When is the strokes playing??
# Prediction: negative | Sentiment: positive
#
# Total: 273 | Correct: 195
# Accuracy: 71.43%

# %%
loaded_classifier = pickle.load(open('models/KNeighborsClassifier.pickle', 'rb'))

df = pd.read_csv('datasets/comments.csv')
df = df.sample(frac=1).reset_index(drop=True) #shuffles the dataframe

sentiment = np.array(df['Sentiment'])
comments = np.array(df['Comment'])

results = []
for comment in comments:
    prediction = loaded_classifier.classify(get_features(comment))
    results.append(prediction)

wrong = 0
for i in range(0, len(results)):
    if results[i] != sentiment[i]:
        print(F"\nTweet: {comments[i]}")
        print(F"Prediction: {results[i]} | Sentiment: {sentiment[i]}")
        wrong += 1

total = len(results)
print(F"\nTotal Predictions: {total} | Wrong Predictions: {wrong}")
# Out:
# Tweet: Anyone needs Ga tickets? I’m selling 3 tickets for a reduced price ❤️❤️👏
# Prediction: negative | Sentiment: positive
#
# Tweet: The strokes & The 1975 ❤️
# Prediction: negative | Sentiment: positive
#
# Tweet: Dah ada single day pass ni it’s up to you nak beli ke tak. Tak perlu nak royanan intelektual sangat lah. Dah ada options kan?😁🤷🏽‍♀️
# Prediction: negative | Sentiment: positive
#
# Tweet: IM GOING ON SATURDAY
# Prediction: negative | Sentiment: positive
#
# Tweet: yall better add in frank ocean
# Prediction: negative | Sentiment: positive
#
# Tweet: @ddrew.13 Saturday dpr hahhahah
# Prediction: negative | Sentiment: positive
#
# Tweet: Hi @goodvibesfest , may I know if we have to choose a specified date upon purchase tomorrow? Or the ticket allows just any one of the days that we can decide later?
# Prediction: negative | Sentiment: positive
#
# Tweet: Die die die die
# Prediction: positive | Sentiment: negative
#
# Tweet: @goodvibesfest can i upgrade my GA ticket to VIP (3day pass)? if yes, how do i make the extra payment? thanks!
# Prediction: negative | Sentiment: positive
#
# Tweet: Ini macam laa 🙌
# Prediction: negative | Sentiment: positive
#
# Tweet: Does anyone need two tickets, selling below the price I got it Dm if interested 🌅
# Prediction: negative | Sentiment: positive
#
# Tweet: 338 on sunday
# Prediction: negative | Sentiment: positive
#
# Tweet: Anyone wanna swap 3 days tix with VIP single day on sunday?
# Prediction: negative | Sentiment: positive
#
# Tweet: Wow the prices 😅
# Prediction: negative | Sentiment: positive
#
# Tweet: Hi! Thanks for your comments. We heard your feedback - so we made the decision to launch VIP Single Day passes in order to make it more accessible. If you have any further concerns, please DM us and we will be happy to attend to you.
# Prediction: negative | Sentiment: positive
#
# Tweet: new jeans
# Prediction: negative | Sentiment: positive
#
# Tweet: Anybody know what day is the 1975 playing?
# Prediction: negative | Sentiment: positive
#
# Tweet: the strokes 😭😭😭😭😭🥲🥲🥲🥲🥲
# Prediction: negative | Sentiment: positive
#
# Tweet: The strokes will be performing on sunday guys. Jom @khairi.nazmi amik sunday je 🤭
# Prediction: negative | Sentiment: positive
#
# Tweet: It was RM300++ for 2 days admission before this.....
# Prediction: positive | Sentiment: negative
#
# Tweet: 🫶🏽 dpr we gang gang 🫶🏽
# Prediction: negative | Sentiment: positive
#
# Tweet: Kasiii on @hasnehafez @ns.mrzk @nadiahafifa
# Prediction: negative | Sentiment: positive
#
# Tweet: Hello @goodvibesfest can u make a seperate list band will be play friday , Saturday and sunday
# Prediction: negative | Sentiment: positive
#
# Tweet: How is this fair for the early ticket buyers. You better be joking GVF
# Prediction: positive | Sentiment: negative
#
# Tweet: hello @goodvibesfest , please add @tillybirds and @ayase_yoasobi in the line up please 🥹🙏🏾🥹
# Prediction: negative | Sentiment: positive
#
# Tweet: GOODVIBES IS SUCH A JOKE NEXT TIME FOR SURE I BOIKOT WEH
# Prediction: positive | Sentiment: negative
#
# Tweet: In true Malaysian fashion, everyone just like to complain. take your bad vibes with you, we don’t need it at a festival that’s literally called good vibes ❤️
# Prediction: positive | Sentiment: negative
#
# Tweet: Siapa nak swap, 2x ticket 3 day pass dengan 2x 1 day pass vip @inayrasina
# Prediction: negative | Sentiment: positive
#
# Tweet: This should be price for 3days. 😪 changed venue next gvf plss.
# Prediction: positive | Sentiment: negative
#
# Tweet: @amin.jali  min? mcm mane kira jadi ke
# Prediction: negative | Sentiment: positive
#
# Tweet: @dermotkennedy  on friday aaaaa @wanadamz
# Prediction: negative | Sentiment: positive
#
# Tweet: I'm selling 3x tickets 🎟️
# Prediction: negative | Sentiment: positive
#
# Tweet: @haziqasfa the strokes plak. Amacam kasi jalan ?
# Prediction: negative | Sentiment: positive
#
# Tweet: Price not worth it 💸
# Prediction: positive | Sentiment: negative
#
# Tweet: Swap ticket: 2x ticket 3 day pass (ga) dengan 2x ticket 1 day pass (vip).
# Prediction: negative | Sentiment: positive
#
# Tweet: anyone yang nak beli tiket vip untuk hari sabtu 22/7/2023 please hmu 🙏🏻 tengah cari geng untuk pergi ni 🥹
# Prediction: negative | Sentiment: positive
#
# Tweet: @zaidalmalum depa dh ada one day pass
# Prediction: negative | Sentiment: positive
#
# Tweet: This is totally different vibes compared to previous one at genting. Ticket too expensive. Venue too hot.
# Prediction: positive | Sentiment: negative
#
# Tweet: 1day pass please? 🙏🏽🙏🏽🙏🏽
# Prediction: negative | Sentiment: positive
#
# Tweet: majulah strokes untuk negara
# Prediction: negative | Sentiment: positive
#
# Tweet: When is the strokes playing??
# Prediction: negative | Sentiment: positive
#
# Tweet: The price is too highhhh
# Prediction: positive | Sentiment: negative
#
# Tweet: Kalau ada kawan kawan nak ticket good vibes tapi hari jumaat roger saya ,harga rm 338
# Prediction: negative | Sentiment: positive
#
# Tweet: Organiser this is absurd
# Prediction: positive | Sentiment: negative
#
# Tweet: Could you guys atleast release the lineup schedule first? How do i know wich day to but if i don’t know who’s performing on which dates??
# Prediction: positive | Sentiment: negative
#
# Tweet: Anak2 sekalian, dari awal lagi GVF ada inform dekat website for 1 day Pass. You guys overlooked la ni. But indeed for VIP passes nampak tak fair dekat situ sebab tiba2 je announce ada pulak 1 day pass utk vip. Sebelum ni memang takda, maybe takramai yg beli tix la tu. So pergi la u all tengok lineup perform hari apa di website ya.
# Prediction: negative | Sentiment: positive
#
# Tweet: Hahahahahaha asal semua marah2 ni hahahahaha
# Prediction: negative | Sentiment: positive
#
# Tweet: LIST OF WHICH ARTIST PLAYING ON WHICH DAY IS ON THEIR WEBSITE GUYS!
# Prediction: negative | Sentiment: positive
#
# Tweet: Swaping 3 days ticket (GA) for 1 day ticket (VIP), total 3 tickets available. We just wanna see Porter Robinson & Gryffin! They are performing on Friday most likely based on their personal schedule.
# Prediction: negative | Sentiment: positive
#
# Tweet: The 1975 main bila???
# Prediction: negative | Sentiment: positive
#
# Tweet: @_fardgazi ejas single pass
# Prediction: negative | Sentiment: positive
#
# Tweet: Boleh ajak @foofighters datang ?
# Prediction: negative | Sentiment: positive
#
# Tweet: Takdok kijoan aku nk g sepang. Panah cheng
# Prediction: positive | Sentiment: negative
#
# Tweet: nk ticket satu hari . lpstu nk tahu full list dulu baru beli .
# Prediction: negative | Sentiment: positive
#
# Tweet: @dalilalyana  aku nmpk kau like
# Prediction: negative | Sentiment: positive
#
# Tweet: to those who wanted a single day pass cheaper price than the one they offer, do pm me as i bought the ticket during the first phase & i just wanna go for one day (sunday)
# Prediction: negative | Sentiment: positive
#
# Tweet: hi guys, im selling my 3 days pass for RM1500 (can pay in installments). lemme know if ure interested!
# Prediction: negative | Sentiment: positive
#
# Tweet: I have 2 extra tickets if anyone wants them hmu
# Prediction: negative | Sentiment: positive
#
# Tweet: How is this fair for the previous buyer whom bought VIP at Phase 1 🥸🥸🥸. You must be joking GVF
# Prediction: positive | Sentiment: negative
#
# Tweet: @masha_elmy woweeeee
# Prediction: negative | Sentiment: positive
#
# Tweet: when is @peachtreerascal performing ?? PLEASEE I JUST WANNA SEE THEM 😭😭
# Prediction: negative | Sentiment: positive
#
# Tweet: Bro if its not mgk, post malone or halsey for second lineup announcement imma rage!
# Prediction: positive | Sentiment: negative
#
# Tweet: Nak tgnk the strokes je
# Prediction: negative | Sentiment: positive
#
# Tweet: Pale butoh ah organiser. Aku dah beli ticket baru nak announce. Kimakkkkk
# Prediction: positive | Sentiment: negative
#
# Tweet: @jaa.dore kita pergi yg ada rini
# Prediction: negative | Sentiment: positive
#
# Tweet: Jika Anda memiliki masalah dengan pembayaran dengan atom saya memiliki tiket saya untuk dijual dan saya menjual di bawah nilai nominal silakan geser di dm saya jika Anda tertarik o
# Prediction: negative | Sentiment: positive
#
# Tweet: @__d.nial @mvhammadfirdavs dia bukak harga baru ni satu hari punya pass mampu milik jom hahahaha
# Prediction: negative | Sentiment: positive
#
# Tweet: Dah elok2 kat genting tiber tukar venue sepang
# Prediction: positive | Sentiment: negative
#
# Tweet: Tak best mmg aku takkan beli!!!!!!!!!!!!!!!
# Prediction: positive | Sentiment: negative
#
# Tweet: @aliffisgood @monkeysmileme @ts0230 hah got 1 day vip pass hahahahha
# Prediction: negative | Sentiment: positive
#
# Tweet: LIMITED HUH
# Prediction: positive | Sentiment: negative
#
# Tweet: zzzzz Baik beli 3 days pss
# Prediction: positive | Sentiment: negative
#
# Tweet: Lets fucking gooooo
# Prediction: negative | Sentiment: positive
#
# Tweet: Got my VIP passes just to see  @dermotkennedy 🔥🙌
# Prediction: negative | Sentiment: positive
#
# Tweet: cam syiokkk je @nurainizati
# Prediction: negative | Sentiment: positive
#
# Tweet: Song 10/10
# Prediction: negative | Sentiment: positive
#
# Tweet: @emilee.val_ why no ajak sayaaaa
# Prediction: negative | Sentiment: positive
#
# Tweet: @a_story_begin we have a new mission. Lets duit
# Prediction: negative | Sentiment: positive
#
# Total Predictions: 273 | Wrong Predictions: 78
